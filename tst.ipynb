# %%
from PIL import Image
import os
import numpy as np

path = r'D:\pic'

# im = Image.open(os.path.join(path,'1.jpg'))
# 
# w, h = im.size
# print('Original image size: %sx%s' % (w, h))
# 
# # im.thumbnail((w//2, h//2))
# # print('Resize image to: %sx%s' % (w//2, h//2))
# 
# im.show()

# %%
import matplotlib.pyplot as plt

im = plt.imread(os.path.join(path, 'origin.jpg'))
plt.imshow(im)

plt.show()

# %%
im.shape
# Out:
# (411, 883, 3)

# %%
plt.imshow(im[:, :, 0])
plt.show()

# %%
plt.imshow(im[:, :, 1])
plt.show()

# %%
plt.imshow(im,cmap=plt.cm.gray)
plt.show()

# %%
imsolid = np.where(im > 128, 255, 0)
plt.imshow(imsolid, cmap=plt.cm.gray)
plt.show()

# %%
rev = 255 - imsolid
print(rev.shape)
revimg = Image.fromarray(rev[:, :, 0])
revimg.show()
# Out:
# (411, 883, 3)

# %%
arr=[[1,2],[2,3]]
for x,y in arr:
    print([x,y] in arr)
# Out:
# True
# True
